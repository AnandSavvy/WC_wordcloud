# %% [markdown]
# ### Installing packages

# %%
# Here all the installs and imports you will need for your word cloud script and uploader widget

# !pip install Wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload
# !pip install pandoc 
# !pip install sklearn
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\ACER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\ACER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\ACER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Installing C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\fileupload\static -> fileupload
# Up to date: C:\Users\ACER\AppData\Roaming\jupyter\nbextensions\fileupload\extension.js
# Up to date: C:\Users\ACER\AppData\Roaming\jupyter\nbextensions\fileupload\widget.js
# ...

# %% [markdown]
#    ### Importing Libraries

# %%
import wordcloud
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display 
import fileupload 
import io
import sys

# %% [markdown]
#     when That was a lot. All of the installs and imports for your word cloud script and uploader widget have been completed.
#     Then under the file menu above, select CLOSE & HALT. when the notebook has completely shut down , reopen it.
#     To upload your text file, run the following cell that contains all the code for a custom uploader widget. Once we run
#     this cell , a "Browser" button should apper below it.

# %%
# This is the uploader widget

def _upload():
    
    _upload_widget = fileupload.FileUploadWidget()

   
    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} KB)'.format(
            filename, len(decoded.read()) /2 **10))
        file_contents = decoded.getvalue()
        
    _upload_widget.observe(_cb, names= 'data')
    display(_upload_widget)
    
_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))

# %% [markdown]
#     click this button it navigate the window to locate your saved text file.

# %% [markdown]
#     Generete_from_frequencies functions to generate your very own word cloud.

# %%
def calculate_frequencies(file_contents):
# Here is a list of all punctuations and uninteresting words you can use to process your text
    punctuations = ''' !()-[]{};:'"\,<>./?@#$%^&_~'''
    uninteresting_words = ["the","a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
                          "we", "our", "ours", "you", "your", "he", "she", "him", "his", "her", "hers", "its", "they", "them",\
                          "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being",\
                          "have", "has", "had", "do", "done", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
                          "all", "any", "both", "each", "few", "more", "some", "liked", "loved", "most", "important", "thing", "such", "no", "nor", "too", "very", "can", "will", "just"]
    
    
      
    
    frequencies = {}
    file_contents = file_contents.split()
    str1 = ""
    
    for word in file_contents:
        str1= ''.join(ch for ch in word if ch.isalnum())
        if str1.lower() not in uninteresting_words:
            if str1.lower() not in frequencies:
                frequencies[str1.lower()]=1
            else:
                frequencies[str1.lower()]=+1
                
#wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(frequencies)
    return cloud.to_array()

# %%
#Display your word cloud image
myimage = calculate_frequencies(file_contents)
myimage
background_color = 'white'

# %%
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
#facecolor = 'white'
plt.rcParams['figure.figsize'] = (30, 28)
#plt.imshow(wordcloud)
plt.show()
